# %%
import os
import mne
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pickle

# %%
# Set directory of raw data (use data in sleep-cassette folder) and pre-processed data
rawDir = "./data/sleep-edf-database-expanded-1.0.0/sleep-cassette"
dest_path = "./data/preprocessed/all_data.pkl"

# Match each psg file with corresponding hypnogram (sleep stage annotation) file. We only use the 2nd night recording for each patient, which is identified by the '2'.
psg_hyp = []
for file in os.listdir(rawDir):
    if file.endswith("PSG.edf") and file[5] == '2':
        psgTemp = file
    elif file.endswith("Hypnogram.edf") and file[5] == '2':
        if psgTemp[0:5] == file[0:5]:
            psg_hyp.append((psgTemp, file))

rows = []
# psg_hyp = [('SC4001E0-PSG.edf', 'SC4001EC-Hypnogram.edf')]    # For debugging with 1 patient


mapping = {'EOG horizontal': 'eog',
           'Resp oro-nasal': 'resp',
           'EMG submental': 'emg',
           'Temp rectal': 'misc',
           'Event marker': 'misc'}

annotation_desc_2_event_id = {'Sleep stage W': 0,
                              'Sleep stage 1': 1,
                              'Sleep stage 2': 2,
                              'Sleep stage 3': 3,
                              'Sleep stage 4': 3,
                              'Sleep stage R': 4}

event_id = {'Sleep stage W': 0,
        'Sleep stage 1': 1,
        'Sleep stage 2': 2,
        'Sleep stage 3/4': 3,
        'Sleep stage R': 4}


all_epochs = []
Npatients = len(psg_hyp)

# based on specs in referenced paper in proposal
epoch_duration = 60.0

for i, (psgFile, hypFile) in enumerate(psg_hyp):
    pID = psgFile[3:5]    
    print(f"Patient {i:3d}/{Npatients}")
    # get our data into epochs
    raw = mne.io.read_raw_edf(os.path.join(rawDir, psgFile))
    annot = mne.read_annotations(os.path.join(rawDir, hypFile))
    raw.set_annotations(annot, emit_warning = False)
    raw.set_channel_types(mapping)
    # Double check if sampling freq is 100 Hz
    fs = int(raw.info['sfreq'])
    assert(fs == 100)
    assert(raw['EEG Fpz-Cz'][1][100] == 1)
    # remove head and tail of our recording 
    annot.crop(annot[1]['onset'] - 30 * 60, annot[-2]['onset'] + 30 * 60)
    raw.set_annotations(annot, emit_warning=False)
    # split into epochs
    events, _ = mne.events_from_annotations(raw, event_id=annotation_desc_2_event_id, chunk_duration=epoch_duration)
    tmax = epoch_duration - 1. / raw.info['sfreq']  # tmax in included
    try:
        # Currently the code breaks if the PSG file does not include at least one of each sleep stage (eg: for pID = 20, there is no sleep stage 3/4). I don't know how to fix this so we just ignore that file.
        epochs = mne.Epochs(raw=raw, events=events, tmin=0., tmax=tmax, baseline=None, picks = ['EEG Fpz-Cz'])
    except Exception as ex:
        print(ex)
    
    # push all our epochs into a list
    epochs.drop_bad()
    
    epochs_data = epochs.get_data("EEG Fpz-Cz")
    epochs_data = np.squeeze(epochs_data)
    epochs_y = epochs.events[:,-1].flatten()
    Nepochs = epochs_data.shape[0]
    
    for i in range(Nepochs):
        all_epochs.append((int(pID), epochs_y[i], epochs_data[i,:].flatten()))
# Out:
# Patient   0/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4002E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 516 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 516 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 516 events and 6000 original time points ...
# Patient   1/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4012E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 543 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 543 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 543 events and 6000 original time points ...
# Patient   2/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4022E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 451 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 451 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 451 events and 6000 original time points ...
# Patient   3/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4032E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 415 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 415 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 415 events and 6000 original time points ...
# Patient   4/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4042E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 551 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 551 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 551 events and 6000 original time points ...
# Patient   5/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4052E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 579 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 579 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 579 events and 6000 original time points ...
# Patient   6/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4062E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 478 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 478 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 478 events and 6000 original time points ...
# Patient   7/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4072E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 578 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 578 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 578 events and 6000 original time points ...
# Patient   8/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4082E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 476 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 476 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 476 events and 6000 original time points ...
# Patient   9/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4092E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 574 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 574 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 574 events and 6000 original time points ...
# Patient  10/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4102E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 514 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 514 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 514 events and 6000 original time points ...
# Patient  11/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4112E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 358 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 358 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 358 events and 6000 original time points ...
# Patient  12/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4122E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 436 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 436 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 436 events and 6000 original time points ...
# Patient  13/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4142E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 436 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 436 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 436 events and 6000 original time points ...
# Patient  14/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4152E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 853 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 853 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 853 events and 6000 original time points ...
# Patient  15/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4162E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 463 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 463 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 463 events and 6000 original time points ...
# Patient  16/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4172E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 829 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 829 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 829 events and 6000 original time points ...
# Patient  17/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4182E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 430 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 430 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 430 events and 6000 original time points ...
# Patient  18/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4192E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 604 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 604 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 604 events and 6000 original time points ...
# Patient  19/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4202E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 496 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 496 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 496 events and 6000 original time points ...
# Patient  20/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4212E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 384 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 384 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 384 events and 6000 original time points ...
# Patient  21/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4222E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 497 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 497 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 497 events and 6000 original time points ...
# Patient  22/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4232E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 822 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 822 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 822 events and 6000 original time points ...
# Patient  23/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4242E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 848 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 848 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 848 events and 6000 original time points ...
# Patient  24/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4252E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 464 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 464 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 464 events and 6000 original time points ...
# Patient  25/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4262F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 462 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 462 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 462 events and 6000 original time points ...
# Patient  26/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4272F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 493 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 493 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 493 events and 6000 original time points ...
# Patient  27/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4282G0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 511 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 511 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 511 events and 6000 original time points ...
# Patient  28/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4292G0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 763 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 763 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 763 events and 6000 original time points ...
# Patient  29/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4302E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 397 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 397 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 397 events and 6000 original time points ...
# Patient  30/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4312E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 511 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 511 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 511 events and 6000 original time points ...
# Patient  31/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4322E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 471 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 471 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 471 events and 6000 original time points ...
# Patient  32/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4332F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 618 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 618 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 618 events and 6000 original time points ...
# Patient  33/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4342F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 761 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 761 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 761 events and 6000 original time points ...
# Patient  34/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4352F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 435 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 435 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 435 events and 6000 original time points ...
# Patient  35/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4362F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 388 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 388 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 388 events and 6000 original time points ...
# Patient  36/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4372F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 737 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 737 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 737 events and 6000 original time points ...
# Patient  37/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4382F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 905 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 905 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 905 events and 6000 original time points ...
# Patient  38/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4402E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 486 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 486 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 486 events and 6000 original time points ...
# Patient  39/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4412E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 407 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 407 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 407 events and 6000 original time points ...
# Patient  40/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4422E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 394 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 394 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 394 events and 6000 original time points ...
# Patient  41/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4432E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 456 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 456 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 456 events and 6000 original time points ...
# Patient  42/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4442E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 499 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 499 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 499 events and 6000 original time points ...
# Patient  43/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4452F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 518 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 518 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 518 events and 6000 original time points ...
# Patient  44/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4462F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 480 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 480 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 480 events and 6000 original time points ...
# Patient  45/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4472F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 1013 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 1013 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 1013 events and 6000 original time points ...
# Patient  46/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4482F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 886 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 886 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 886 events and 6000 original time points ...
# Patient  47/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4492G0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 465 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 465 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 465 events and 6000 original time points ...
# Patient  48/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4502E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 506 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 506 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 506 events and 6000 original time points ...
# Patient  49/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4512E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 449 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 449 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 449 events and 6000 original time points ...
# Patient  50/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4522E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 481 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 481 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 481 events and 6000 original time points ...
# Patient  51/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4532E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 490 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 490 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 490 events and 6000 original time points ...
# Patient  52/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4542F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 494 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 494 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 494 events and 6000 original time points ...
# Patient  53/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4552F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 520 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 520 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 520 events and 6000 original time points ...
# Patient  54/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4562F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 525 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 525 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 525 events and 6000 original time points ...
# Patient  55/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4572F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 508 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 508 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 508 events and 6000 original time points ...
# Patient  56/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4582G0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 536 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 536 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 536 events and 6000 original time points ...
# Patient  57/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4592G0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 528 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 528 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 528 events and 6000 original time points ...
# Patient  58/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4602E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 940 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 940 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 940 events and 6000 original time points ...
# Patient  59/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4612E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 482 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 482 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 482 events and 6000 original time points ...
# Patient  60/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4622E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 849 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 849 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 849 events and 6000 original time points ...
# Patient  61/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4632E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 501 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 501 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 501 events and 6000 original time points ...
# Patient  62/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4642E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 993 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 993 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 993 events and 6000 original time points ...
# Patient  63/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4652E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 825 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 825 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 825 events and 6000 original time points ...
# Patient  64/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4662E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 940 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 940 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 940 events and 6000 original time points ...
# Patient  65/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4672G0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 473 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 473 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 473 events and 6000 original time points ...
# Patient  66/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4702E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 722 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 722 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 722 events and 6000 original time points ...
# Patient  67/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4712E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 577 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 577 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 577 events and 6000 original time points ...
# Patient  68/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4722E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 514 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 514 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 514 events and 6000 original time points ...
# Patient  69/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4732E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 1093 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 1093 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 1093 events and 6000 original time points ...
# Patient  70/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4742E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 511 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 511 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 511 events and 6000 original time points ...
# Patient  71/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4752E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 486 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 486 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 486 events and 6000 original time points ...
# Patient  72/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4762E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 1265 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 1265 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 1265 events and 6000 original time points ...
# Patient  73/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4772G0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 617 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 617 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 617 events and 6000 original time points ...
# Patient  74/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4802G0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 567 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 567 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 567 events and 6000 original time points ...
# Patient  75/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4812G0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 545 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 545 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 545 events and 6000 original time points ...
# Patient  76/77
# Extracting EDF parameters from C:\Users\acidi\Coding\comp9417-project-21t2\data\sleep-edf-database-expanded-1.0.0\sleep-cassette\SC4822G0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Used Annotations descriptions: ['Sleep stage 1', 'Sleep stage 2', 'Sleep stage 3', 'Sleep stage 4', 'Sleep stage R', 'Sleep stage W']
# Not setting metadata
# Not setting metadata
# 634 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 634 events and 6000 original time points ...
# 0 bad epochs dropped
# Loading data for 634 events and 6000 original time points ...

# %%
with open(dest_path, "wb+") as fp:
    pickle.dump(all_epochs, fp)
